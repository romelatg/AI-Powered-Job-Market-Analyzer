# %%
import requests
import json
import pandas as pd

api_key = "YOUR_API_KEY_HERE"

# %%
job_postings = [
    """
    The Spec Analytics Analyst is a developing professional role. Applies specialty area knowledge in monitoring, assessing, analyzing and/or evaluating processes and data. Identifies policy gaps and formulates policies. Interprets data and makes recommendations. Researches and interprets factual information. Identifies inconsistencies in data or results, defines business issues and formulates recommendations on policies, procedures or practices. Integrates established disciplinary knowledge within own specialty area with basic understanding of related industry practices. Good understanding of how the team interacts with others in accomplishing the objectives of the area. Develops working knowledge of industry practices and standards. Limited but direct impact on the business through the quality of the tasks/services provided. Impact of the job holder is restricted to own team.

Responsibilities:

Incumbents work with large and complex data sets (both internal and external data) to evaluate, recommend, and support the implementation of business strategies
Identifies and compiles data sets using a variety of tools (e.g. SQL, Access) to help predict, improve, and measure the success of key business to business outcomes
Responsible for documenting data requirements, data collection / processing / cleaning, and exploratory data analysis; which may include utilizing statistical models / algorithms and data visualization techniques
Incumbents in this role may often be referred to as Data Scientists
Specialization in marketing, risk, digital and AML fields possible
Appropriately assess risk when business decisions are made, demonstrating particular consideration for the firm's reputation and safeguarding Citigroup, its clients and assets, by driving compliance with applicable laws, rules and regulations, adhering to Policy, applying sound ethical judgment regarding personal behavior, conduct and business practices, and escalating, managing and reporting control issues with transparency.

Qualifications:

0-2 years relevant experience
Have the ability to retrieve and manipulation data
Possess analytic ability and problem solving skills
Working experience in a quantitative field
Excellent communication and interpersonal skills, be organized, detail oriented, and adaptive to matrix work environment
Ability to build partnerships with cross-functional teams

Education:

Bachelors/University degree or equivalent experience

This job description provides a high-level review of the types of work performed. Other job-related duties may be assigned as required.

Se espera que cuente con habilidades analíticas, pensamiento lógico, aprendizaje continuo y comunicación efectiva, además de utilizar herramientas de inteligencia artificial y machine learning para apoyar la programación y análisis de datos, manteniendo altos estándares de calidad, seguridad y gobierno de datos.
Conocimiento básico - intermedio SQL, python, programación
Conocimiento básico - intermedio en IA (prompt engineering, RAG, LLM)
Inglés intermedio/ avanzado

------------------------------------------------------

Job Family Group:

Decision Management

------------------------------------------------------

Job Family:

Specialized Analytics (Data Science/Computational Statistics)

------------------------------------------------------

Time Type:

Full time

------------------------------------------------------

Most Relevant Skills

Please see the requirements listed above.

------------------------------------------------------

Other Relevant Skills

For complementary skills, please see above and/or contact the recruiter.
    """,
    """
    About the job
Ready to accelerate your career?

Clara is the fastest-growing company in Latin America. We've built the leading solution for companies to make and manage all their payments. We already help over 20,000 large and growing businesses operate with agility and financial clarity through locally issued corporate cards, bill pay, financing, and a powerful B2B platform built for scale.

Clara is backed by some of the most successful investors in the world, including top regional VCs like monashees, Kaszek, and Canary, and leading global funds like Notable Capital, Coatue, DST Global Partners, ICONIQ Growth, General Catalyst, Citi Ventures, SV Angel, Citius, Endeavor Catalyst, and Goldman Sachs - in addition to dozens of angel investors and local family offices.

We're building the financial infrastructure that powers high-performing organizations across the region. We invite you to join us if you want to be part of a fast-paced environment that will accelerate your career and support you to do some of the best work of your life alongside a passionate and committed team distributed across the Americas.

What you'll do

We're looking for a Data Analyst Associate to join our Data team and help drive decision-making across Clara. In this role, you will be the bridge between raw data and actionable business insights. You will not only report on what is happening but help us understand why it is happening, ensuring our teams have the accurate data they need to move fast and build financial solutions for companies in Latin America.

Design and maintain high-impact dashboards and reports to support critical business decisions.
Conduct deep-dive data analysis to identify trends, patterns, and anomalies that drive product and operational improvements.
Partner closely with data engineers and data scientists to ensure Data Integrity and quality across our pipelines.
Automate reporting workflows to reduce manual effort and increase the speed of insight delivery.
Translate complex datasets into clear, narrative-driven insights for non-technical stakeholders.

Who you are

We're looking for someone who meets the minimum requirements to be considered for the role. The preferred qualifications are a bonus, not a requirement.

Must haves

Working proficiency in English and Spanish.
Degree in Data Science, Statistics, Mathematics, Economics, or related quantitative fields.
Strong proficiency in SQL for database manipulation and querying large datasets.
Proven experience in data analysis, specifically in extracting actionable insights from raw data.
Solid understanding of descriptive statistics and exploratory modeling concepts.
Familiarity with data visualization tools (e.g., Metabase or similar BI platforms).
High attention to detail with a strong emphasis on maintaining data quality, given the financial nature of our business.
Experience or interest in AI tools to automate workflows.
Adaptability to fast-changing environments and a high level of ownership.

Nice to haves

Basic experience with Databricks.
Practical experience with ETL or ELT processes.
Independent analytical skills using Python for more advanced statistical analysis.
Basic proficiency in Portuguese or a desire to learn it and English Fluent.
A good sense of humor.

Why join Clara

At Clara, you'll have the autonomy, speed, and support to make meaningful impact — not just on your team, but on how organizations are run across Latin America.

Who we are

We're the leading B2B fintech for spend management in Latin America.
Certified as one of the world's fastest-growing companies, a Great Place to Work, and a LinkedIn Top Startup.
Passionate about making Latin America more prosperous and competitive.
Constantly innovating to build financial infrastructure that enables each of our customers to thrive.
Product-led, high-talent-density culture — designed for builders who raise the bar.
Proud of our open, inclusive, and values-driven environment.

What we believe in

#Clarity. We say things clearly, directly, and proactively.
#Simplicity. We reduce noise to focus on what really matters.
#Ownership. We take responsibility and never wait to be told.
#Pride. We build products and experiences we're proud of.
#Always Be Changing (ABC). We grow through feedback, risk-taking, and action.
#Inclusivity. Every voice counts. Everyone contributes to our mission.

What we offer

Competitive salary and stock options (ESOP) from day one
Multicultural team with daily exposure to Portuguese, Spanish, and English (our corporate language)
Annual learning budget and internal accelerated development paths
High-ownership environment: we move fast, learn fast, and raise the bar — together
Smart, ambitious teammates — low ego, high impact
Flexible vacation and hybrid work model focused on results

If you're ready for growth, ownership, and impact — apply now and help us redefine B2B finance in Latin America.
    """,
    """
    About the job
Te invitamos a formar parte del equipo regional de especialistas de tecnología y agilidad, con habilidades de abordar distintos desafíos en las iniciativas de innovación tecnológica, permitiéndonos responder a las necesidades en cada uno de nuestros clientes.

En nuestra empresa puedes poner a prueba tus aptitudes y generar valor con una mentalidad de aprendizaje continuo.

Estamos en constante contacto con nuevas tecnologías, múltiples proyectos e

industrias, acompañado de profesionales expertos, académicos y PhDs con una amplia experiencia en el mundo de TI y de negocio.

En Practia Global 🔴 nos encontramos en la búsqueda de un Analista BI / Data Analytics en México.



-

Requisitos:

✅ Experiencia de 3 años o más en roles iguales o similares.

✅ Dominio de Power BI, Tableau, Qlik o herramientas similares.

✅ Conocimiento avanzado de SQL.

✅ Experiencia desarrollando dashboards e indicadores de negocio.

✅ Experiencia en modelado y explotación de datos para toma de decisiones.

.

Te ofrecemos:

🔆 Estabilidad laboral.

🔆 Plan de carrera.

🔆 Somos una empresa con proyección de crecimiento a nivel LATAM.

🔆 Flexibilidad Laboral y de vestimenta.
    """,
    """
    Ubicación: Guadalajara | Esquema híbrido



Requisitos:



Licenciatura en Analítica de Datos, Administración, Sistemas, Finanzas, Ingeniería o carrera afín (Concluida).


Inglés avanzado (mandatorio).


1 año de experiencia en análisis de datos, reporting, business intelligence o entornos de performance management.


Experiencia trabajando con Power BI (desarrollo y mantenimiento de dashboards).


Manejo de Excel y SQL básico.


Capacidad para traducir necesidades de negocio en soluciones de reporting claras.


Responsabilidades principales:



Mantener, actualizar y optimizar dashboards en Power BI, asegurando precisión y confiabilidad de la información.


Monitorear procesos de actualización de datos y resolver temas de calidad en coordinación con equipos técnicos y dueños de la información.


Desarrollar nuevos reportes y visualizaciones que brinden visibilidad al negocio y soporten la toma de decisiones.


Validar y reconciliar información entre dashboards, sistemas fuente y reportes operativos.


Colaborar con distintos stakeholders para entender requerimientos y traducirlos en soluciones de analítica visual.


Documentar métricas, definiciones y lógica de los dashboards para asegurar continuidad y gobernanza.


Dar soporte a ciclos de reporte periódicos (semanales, mensuales y trimestrales).



Requirements added by the job poster

• 1+ years of work experience with Microsoft Power BI

• Bachelor's Degree

• 1+ years of work experience with Microsoft Excel
    """,
    """
    About the job
FBS - Farmer Business Services is part of Farmers operations with the purpose of building a global approach to identifying, recruiting, hiring, and retaining top talent. By combining international reach with US expertise, we build diverse and high-performing teams that are equipped to thrive in today's competitive marketplace.

We believe that the foundation of every successful business lies in having the right people with the right skills. That is where we come in—helping Farmers build a winning team that delivers consistent and sustainable results.

Since we don't have a local legal entity, we've partnered with Capgemini, which acts as the Employer of Record. Capgemini is responsible for managing local payroll and benefits.

What to expect on your journey with us:

A solid and innovative company with a strong market presence
A dynamic, diverse, and multicultural work environment
Leaders with deep market knowledge and strategic vision
Continuous learning and development

Requirements

Summary:

The Business Operations Analyst II supports operational initiatives, technology projects, business optimization, and process improvement efforts across Direct Sales. This role partners with business stakeholders to coordinate projects, gather requirements, build solutions, support automation initiatives, and help streamline day-to-day business processes. The ideal candidate possesses a blend of project coordination, analytical, and technical skills, with experience working with data, reporting tools, business applications, AI, and workflow automations. This individual will contribute to both strategic initiatives and operational support activities while helping drive efficiency, accuracy, and scalability across the organization.

Responsibilities:

Project & Program Support:

Assist with planning, coordinating, and executing operational and technology-focused projects
Track project milestones, risks, dependencies, and action items
Facilitate meetings and document project decisions and requirements
Partner with stakeholders to gather business requirements and translate them into actionable solutions

Reporting & Analytics:

Develop and maintain operational reports, dashboards, and performance metrics
Validate data accuracy and troubleshoot reporting issues
Support business users with data analysis and reporting requests
Identify trends and opportunities for process improvement using data. Automation & Technology Solutions
Support workflow automation initiatives using low-code/no-code platforms
Assist with API integrations, data transfers, and system connectivity efforts
Create and maintain automation documentation and process guides
Help test and validate new system enhancements and technology solutions

Operational Support:

Support day-to-day business processes and operational activities
Monitor recurring processes and troubleshoot issues when they arise
Document standard operating procedures and business workflows
Identify opportunities to improve efficiency, reduce manual effort, and enhance user experience

Tools:

Power Platform - Entry Level (1-3 Years)

Quickbase - Entry Level (1-3 Years)

Salesforce - Entry Level (1-3 Years)

REST APIs - Entry Level (1-3 Years)

Python - Entry Level (1-3 Years)

Snowflake/SQL - Entry Level (1-3 Years)

Microsoft Excel - Entry Level (1-3 Years)

JSON - Entry Level (1-3 Years)

Copilot Studio / AI - Entry Level (1-3 Years)

Benefits

This position comes with a competitive compensation and benefits package.

A competitive salary and performance-based bonuses
Comprehensive benefits package
Flexible work arrangements (remote and/or office-based)
You will also enjoy a dynamic and inclusive work culture within a globally renowned group
Private Health Insurance
Paid Time Off
Training & Development opportunities in partnership with renowned companies
    """,
    """ --On-site role in Puebla, Puebla--

** Role focused on Evening /Night Shyft **

Company Overview

VENTES is now working with a fast-growing, innovative company revolutionizing inventory management and acquisition in a dynamic industry. We are seeking a dedicated Business Operations Associate to join our team, ensuring seamless delivery and management of inventory to meet customer and operational demands.

Job Summary

As a Business Operations Associate, you will be a key player in our Operations team, focusing on the efficient execution of inventory acquisition and fulfillment processes. You will coordinate with remote teams, acquire inventory, manage order processing, and ensure timely and accurate delivery of inventory. This role requires a tech-savvy individual with a keen eye for detail, a passion for gaming, and the ability to thrive in a high-energy environment.

Key Responsibilities

Inventory Management

● Leverage proprietary technology and strategies to purchase inventory in real-time with precision

● Perform routine checks to verify accuracy, condition, and categorization of acquired inventory

● Ensure prompt processing and cataloging of inventory to meet tight operational deadlines

Order Fulfillment

● Oversee end-to-end order fulfillment from receiving acquisition tickets to ensuring accurate and timely delivery

● Coordinate with remote teams and external partners to resolve fulfillment issues and maintain smooth operations

● Utilize inventory management tools and software to streamline fulfillment processes and maintain data accuracy

Process Optimization

● Identify inefficiencies or friction points within the fulfillment workflow

● Suggest improvements to enhance accuracy, speed, or scalability

● Collaborate with operations team to test and implement approved changes

● Execute company goals, track KPIs, and refine strategies for continuous improvement

Required Qualifications

Education & Experience

● Bachelor's degree in Technology, Computer Science, Business, Supply Chain, Logistics, or related field

● 0-3 years of experience in fast-paced environment, preferably in fulfillment, logistics, or inventory management

● Experience with remote team coordination

Technical Skills

● Strong proficiency in Microsoft Excel

● Ability to quickly learn and adapt to new inventory or fulfillment software

● Comfortable utilizing technology to track performance and optimize operations

Core Competencies

● Exceptional organizational skills and meticulous attention to detail, especially in high-pressure settings

● Strong leadership skills with ability to drive initiatives from start to finish

● Experience managing people and leading operational improvements

● Proven ability to manage multiple operational tasks simultaneously while meeting deadlines

● Strong problem-solving skills with ability to identify issues proactively and suggest data-informed solutions

Communication

● Fluent in English (bilingual candidates preferred)

● Strong written and verbal communication for coordination with internal teams, external vendors, and remote colleagues

● Ability to escalate issues effectively and document procedures

Personal Attributes

● Ability to prioritize and perform effectively in fast-evolving, dynamic environments

● Quick decision-making capabilities

● Enthusiasm for gaming culture and trends with understanding of the gaming industry

Preferred Qualifications

● Experience with inventory management or e-commerce fulfillment systems

● Familiarity with gaming-related products or platforms

● Additional experience in process improvement initiatives

Job Details

● Dynamic role advancement potential in a fast-growing company.

● A vibrant, gaming-centric work environment with workplace perks

● Job Type: Full-time

● Schedule: Monday - Saturday (Day and Evening shifts available, with preference to the evening shifts.

● Work Location: Puebla, México (on-site)

Job Type: Full-time

Pay: $16,000.00 - $20,000.00 per month

Application Question(s):

E-Commerce: 1 year (Required)
Social Media Management or Marketing: 1 year (Preferred)
Do you live in Puebla City?
Language:

English (Required)""",
    """ Sears busca DATA ANALYST en Plaza Carso - Miguel Hidalgo, Ciudad de México
Analista de Datos (People Analytics)

En Sears México creemos que las personas son el motor de nuestro crecimiento. Con más de 100 tiendas y presencia a nivel nacional, formamos parte de una organización en constante evolución, donde los datos se han convertido en una herramienta clave para fortalecer la estrategia de Capital Humano.
Por ello, estamos buscando un(a) Analista de People Analytics que quiera formar parte de nuestro equipo corporativo de Recursos Humanos, contribuyendo al análisis de información, la generación de insights y la construcción de soluciones que ayuden a tomar decisiones estratégicas sobre nuestro talento.
Funciones

Análisis de indicadores de RH.
Elaboración de dashboards y reportes ejecutivos.
Detección de tendencias y oportunidades de mejora.
Automatización de reportes y procesos.
Generación de recomendaciones basadas en datos.
Participación en proyectos estratégicos de People Analytics.
Requisitos

Licenciatura en Actuaría, Matemáticas Aplicadas, Economía o Administración.
Experiencia de 1 a 2 años en análisis de datos, BI o People Analytics.
Excel Intermedio Avanzado.
Manejo de Power BI (indispensable).
Manejo de bases de datos.
Afinidad con herramientas de IA (Copilot, Chat GPT, Gemini)
Competencias como autogestión, iniciativa, dinamismo, pensamiento analítico.
Te ofrecemos:

Contrato directo con el Grupo.
Prestaciones de ley y superiores.
Oportunidades de crecimiento.""",
    """Descripción completa del empleo
Actualmente tenemos abierta la vacante de:

*ANALISTA DE DATOS*

*¿Qué buscamos en ti?*

- Edad: 25 a 50 años

- Sexo: Indistinto

- Experiencia comprobable en análisis de datos, administración, contabilidad o afín

- Manejo de Excel, bases de datos y reportes

- Persona organizada, analítica y responsable

- Con habilidades de manejo de carro

*¿Qué ofrecemos?*

En La Flor de Jalisco valoramos tu trabajo, por eso te ofrecemos estabilidad y crecimiento:

- *Sueldo de $12,000 mensuales* con pago semanal puntual

- *Horario fijo de Lunes a Sábado de 8:00 AM a 5:00 PM* - ¡Valoramos tu tiempo en familia!

- *Todas las prestaciones de ley* desde el primer día (IMSS, INFONAVIT, aguinaldo, vacaciones)

- Uniforme sin costo

- Reparto de utilidades

- Excelente ambiente laboral y oportunidad de crecimiento en empresa 100% sonorense

*Lugar de trabajo:* Sucursal Matriz, Col. Yucatán, GUAYMAS SON.""",
    """ FOOD SOLUTIONS, NUTRIBITS solicita:

Analista de datos Jr / Analista Comercial / KAM JR

Objetivo del puesto:

Gestionar cuentas asignadas dentro del canal retail, maximizando la rentabilidad y la presencia de marca, con visión de crecimiento hacia la administración autónoma de cuentas estratégicas.

Monitoreo de inventario, seguimiento a traslado logístico.

Competencias requeridas:

(Conoce datos, ejecución en punto de venta y relacion directa con cadenas)

Análisis de datos y reportes (Excel / Power BI)

Impresión y resguardo de documentos, seguimiento facturas, archivo...

Importante:

Manejo de Office y Excel ( Intermedio - Avanzado)
Se aplica ejercicio XLS
Todas las prestaciones de ley.

$15,000 pesos mensuales menos impuestos. Esquema de pago quincenal.

Horario de oficina: 8 am a 6 pm Lunes a Viernes

Sábado 3 horas.

Nos ubicamos en Apodaca Nuevo León (Zona Huinalá) a 5 min del centro zapatero Huinalá.

Interesados favor de postularse por este medio

Tipo de puesto: Tiempo completo

Sueldo: $14,500.00 - $15,000.00 al mes

Beneficios:

Descuento de empleados
Estacionamiento de la empresa
Opción a contrato indefinido
Pregunta(s) de postulación:

Menciona el manejo de Excel Actual :
Menciona tu ultima percepcion economica , incluye si contabas con alguna prestacion adicional a las de la ley :
Menciona tu percepción deseada en base a tus necesidades :""",
    """ Descripción completa del empleo
Giginer busca Power BI Developer en Nava, Coahuila de Zaragoza
Buscamos Power BI Developer


Tareas


Desarrollo de nuevos productos de datos
Soporte a productos existentes (tickets y solicitudes de cambio)
Mejorar storytelling
Identificación de insights en datos
Documentación

Skills


Capacidad de análisis
Excelente comunicación
Actitud de servicio
Python (ETLs y análisis de datos)
SQL
Modelado de datos
Power BI (profundo conocimiento en power bi services : dataflow, dataset, Dax )
Power Apps (power automate, power apps)
Conocimiento deseable en tecnologías cloud (aws,snowflake)

Idiomas


Inglés avanzado

Horario: 08:00 a 17:30 de lunes a viernes.


Ubicación: Nava Coahuila Nuevo León""",
    """ Descripción completa del empleo
SI-Crea Comercial, S.A. de C.V busca Analista Jr de Base de Datos en Benito Juárez, Ciudad de México
En Grupo SICREA, empresa líder en servicios financieros, buscamos talento para integrarse a nuestro equipo como Analista Jr de Base de Datos en la alcaldía Benito Juárez, Ciudad de México.


Responsabilidades:

Administrar y optimizar bases de datos.
Coordinar la recolección de información
Procesar y analizar la información recibida de diferentes canales det ecnología utilizando técnicas estadísticas
Realizar diagnósticos y seguimientos periódicos de los procesos actuales a fin de mantener un servicio sano para los clientes
Definir planes para la optimación de nuevas herramientas digitales
Generar informes,reportes y métricas de valor que ayuden al crecimiento del negocio.
Gestionar y garantizar elcumplimiento de los procesos de proyectos en la ejecución de la política,los estándares,los procesos, etc.

Requisitos:

Escolaridad: Actuaría, Economía, afín (Titulados)
Experiencia mínima de 1 año trabajando con bases de datos en el sector financiero.
Manejo intermedio de SQL, Excel y Power Bi.
Orientación al detalle, organización y trabajo en equipo.
Disponibilidad para laborar de forma presencial en Benito Juárez, Ciudad de México.

Ofrecemos / Beneficios

Sueldo mensual bruto de $20,000 a $22,000 (con base en experiencia).
Prestaciones de ley y superiores.""",
    """ Descripción completa del empleo
Power BI
Consultas SQL y conocimiento de bases de datos relacionales (SQL Server, PostgreSQL).
Procesos ETL y manejo de pipelines de datos (extracción, transformación y carga).
Conocimiento de entornos de Data Lake, Data Warehouse y modelado dimensional.
Sueldo: $18,000.00 - $19,000.00 al mes""",
    """ Descripción completa del empleo
Objetivo:

Apoyar al área con la gestión, control y análisis profundo de la información generada por la organización. Interactuar con los datos de las diferentes áreas para actualizar, automatizar y estructurar reportes y procesos, transformando la información en tableros de inteligencia de negocios (BI) que faciliten y optimicen la toma de decisiones gerenciales y operativas.

Funciones principales:

Gestión y Control de Información
Análisis de Datos
Elaboración de BI y Automatización
Interacción Interdepartamental
Presentación de Resultados
Perfil:
Licenciatura concluida en Actuaría, Economía, Matemáticas Aplicadas, Estadística o áreas afines.

Mínimo 1 año de experiencia comprobable en Inteligencia de Negocios (BI), análisis de información y gestión de bases de datos.

Requisitos:

Fuerte dominio y gestión de bases de datos.
Sólidas habilidades en el desarrollo de análisis de información estructurada.
Elaboración e implementación de soluciones de Business Intelligence.
Microsoft Excel: Nivel Avanzado (fórmulas complejas, macros, Power Query, manejo de grandes volúmenes de datos).
Sistemas ERP: Experiencia deseable en el uso y extracción de datos desde SAP.
Power BI.
Competencias:

· Gusto por el manejo de información.

· Tolerancia a la frustración

· Proactividad

· Trabajo en equipo

Ofrecemos:

Sueldo mensual $12,000-$13,000 brutos

Prestaciones de Ley, seguro de vida, buen ambiente laboral

Sueldo: $12,000.00 - $13,000.00 al mes

Lugar de trabajo: Empleo presencial""",
    """ Ubicación
Huejotzingo, Pue.
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Capacitación continua
Vales de despensa
Ayuda o servicio de transporte
Servicio de comedor
Oportunidades de crecimiento
&nbsp;
Descripción completa del empleo
AJEMEX es una reconocida empresa internacional en la industria de bebidas con más de 36 años de experiencia, nos hemos destacado por brindar soluciones integrales y eficientes a nuestros clientes. Trabajar en AJEMEX significa formar parte de un equipo comprometido, profesional y con un ambiente laboral colaborativo. Valoramos el desarrollo personal y profesional de nuestros empleados, brindando oportunidades de crecimiento y capacitación continua.

Misión del puesto: Responsable de la captura, validación y seguimiento de pedidos, asegurando la correcta administración de la información y brindando soporte a las áreas involucradas.

Zona de trabajo: Huejotzingo, Puebla

Requisitos del puesto/Actividades:

Experiencia 1 año en giro afin
Ing. Industrial, Relaciones industriales, comerciales o afin.
Capturar y liberar pedidos en sistema ERP interno.
Dar seguimiento al estatus de pedidos.
Atender correos y llamadas de áreas internas y comerciales.
Realizar ajustes, cancelaciones y actualizaciones de pedidos.
Actualizar formatos e información en sistema.
Generar reportes y consultas en SQL.
Administrar información en ERP interno y Drive.
Apoyar a las áreas Comercial y Programación con información de pedidos.
Ofrecemos

Salario base competitivo
Vales de despensa
Comedor subsidiado
Transporte de personal (zonas Puebla y San Martín Texmelucan)
Fondo de ahorro
Prestaciones de ley desde el primer día
Estabilidad laboral
Seguro 360
Plan de crecimiento
Intégrate a nuestro equipo!

Tipo de puesto: Tiempo completo, Por tiempo indeterminado

Sueldo: $14,000.00 al mes""",
    """ Descripción completa del empleo
Data Analytics Jr (Medio tiempo o Tiempo completo)

Ubicación: Edificio ORVIT, Fracc. Piamonte, El Marqués, Querétaro

Horario: Lunes a viernes de 9:00 am a 2:00 pm y de 4:00 pm a 7:00 pm (horario a definir según modalidad)

¿Estás estudiando o recién egresado de una carrera en ingeniería o afín con conocimientos en programación? Esta oportunidad puede ser para ti.

En esta posición apoyarás a un equipo que brinda servicios de análisis de datos para las áreas de Impuestos, Comercio Exterior, Auditoría y, posteriormente, clientes externos. El reto principal será la automatización de procesos internos y el desarrollo de soluciones para clientes.

Conocimientos indispensables:

Conocimientos intermedios/avanzados de programación en ,
Python
SQL,
Power BI
RPA
Excel intermedio
Conocimientos deseables:

Experiencia en fronend
Competencias requeridas:

Pensamiento analítico
Comunicación asertiva
Enfoque en resultados
Trabajo colaborativo
Orientación al servicio
Autodirección
Inglés: Mínimo nivel B1

Perfil: Estudiantes o recién egresados (nivel Junior)

Tipo de contrato: Medio tiempo o tiempo completo (según disponibilidad)

Sueldo: A definir según el horario cubierto

Prestaciones: Prestaciones de ley y seguro de gastos médicos mayores después del tercer mes

Sueldo: De acuerdo a la experiencia

Sueldo: $11,000.00 - $16,000.00 al mes

Pregunta(s) de postulación:

Vivir cerca de la ubicación o contar con auto?
• Conocimientos intermedios/avanzados de programación en Python
Conocimientos intermedios/avanzados de programación en SQL
Conocimientos intermedios/avanzados de programación en POWER BI
Conocimientos intermedios/avanzados de programación en RPA
• Experiencia en fronend
Lugar de trabajo: Empleo presencial

""",
    """ Descripción completa del empleo
WE ARE LOOKING FOR TALENT

Make the Perfect Match!

ANALISTA DE SOPORTE ERP Y REPORTES

Puebla – Zona La Paz | Presencial | Tiempo completo

¿Cuál será tu misión?

Brindar soporte técnico y funcional a usuarios del ERP, generando reportes e indicadores que apoyen la operación del negocio mediante el uso de SQL y herramientas de Business Intelligence como Power BI o Tableau.

Lo que harás:

Brindar soporte técnico de primer nivel a usuarios del ERP.
Atender y dar seguimiento a incidencias funcionales y técnicas.
Generar reportes operativos y ejecutivos mediante consultas SQL.
Desarrollar y actualizar dashboards en Power BI o Tableau.
Extraer, analizar y validar información proveniente del ERP.
Crear consultas y sentencias SQL para obtener información de negocio.
Apoyar en configuraciones básicas y seguimiento de incidencias del sistema.
Colaborar con consultores y usuarios para atender requerimientos de información.
Documentar incidencias, soluciones y solicitudes de mejora.
Dar seguimiento a tickets hasta su resolución.
Indicadores clave:

Tiempo de respuesta a tickets.
Tiempo de resolución de incidencias.
Exactitud de los reportes generados.
Disponibilidad de dashboards.
Satisfacción de usuarios internos y clientes.
Cumplimiento de solicitudes de información.
Lo que buscamos:

Experiencia mínima de 1 a 2 años en soporte técnico o soporte funcional de ERP.
Experiencia utilizando cualquier ERP (Microsip es un plus).
Conocimiento intermedio de SQL (consultas, joins, filtros, sentencias).
Manejo de Power BI o Tableau para generación de reportes.
Conocimiento básico de bases de datos.
Facilidad para analizar información y resolver problemas.
Excelente actitud de servicio y atención a usuarios.
Organización y seguimiento de actividades.
Trabajo en equipo y comunicación efectiva.
Conocimientos deseables:

Microsip.
Crystal Reports, Report Builder o FastReport.
PostgreSQL.
Windows y Microsoft Office.
Redes básicas.
Procesos administrativos, contables o de nómina.
Requisitos:

Licenciatura o Ingeniería en Sistemas, Tecnologías de la Información, Informática o afín.
Disponibilidad para trabajar de forma presencial en Puebla.
Experiencia brindando soporte a usuarios.
Interés por desarrollarse en análisis de datos y herramientas de Business Intelligence.""",
    """ Descripción completa del empleo
MODATELAS busca Analista de Base de Datos en Cuajimalpa de Morelos, Ciudad de México
Analista de Datos


Objetivo:


Buscamos un Analista de Datos para el área de Mercaderías que sea responsable de analizar información comercial, inventarios y ventas para generar indicadores y recomendaciones que impulsen la rentabilidad del negocio.


Requisitos


Licenciatura concluida.


Experiencia mínima de 2 años en análisis de datos.


Excel Avanzado.


Power BI.


SQL.


Manejo de bases de datos.


Deseable experiencia en retail.


Principales responsabilidades


Análisis de ventas e inventarios.
Elaboración de dashboards.
Forecast de demanda.
Indicadores comerciales.
Automatización de reportes.
Presentación de resultados.

Ofrecemos


Sueldo $13,000 brutos mensuales
Prestaciones de ley y superiores.
Desarrollo profesional.""",
    """ Huejotzingo, Pue.
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Servicio de transporte
Ayuda o servicio de transporte
Oportunidades de crecimiento
&nbsp;
Descripción completa del empleo
Analista de Datos de Producción
Skytex México somos una empresa líder en la industria textil, comprometida con la innovación, la calidad y la mejora continua. Buscamos talento analítico que contribuya a transformar los datos en información estratégica para optimizar nuestros procesos de producción.

Requisitos
Ingeniería Industrial, o carrera afín.
2 años de experiencia en análisis de datos en empresas manufactureras.
Excel avanzado (indispensable).
Power BI (deseable).
Conocimientos
Análisis e interpretación de datos.
Excel avanzado.
Indicadores de producción (KPIs).
Estadística aplicada.
Elaboración de reportes ejecutivos.
Desarrollo de tableros de control (Dashboards).
Análisis de productividad, eficiencia, OEE, mermas y tiempos de producción.
Manejo de bases de datos.
Actividades
Analizar información de producción para la toma de decisiones.
Elaborar reportes e indicadores de desempeño.
Diseñar dashboards de seguimiento.
Detectar desviaciones y oportunidades de mejora.
Dar seguimiento a indicadores de productividad y eficiencia.
Apoyar en proyectos de mejora continua.
Competencias: Pensamiento analítico, orientación a resultados, organización, atención al detalle y trabajo en equipo.

Ofrecemos
Sueldo competitivo.
Prestaciones de ley.
Servicio de transporte.
Uniformes.
Oportunidad de desarrollo profesional.
Estabilidad laboral.
Excelente ambiente de trabajo.""",
    """ bicación
Guadalajara, Jal.
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Seguro de vida
Vales de despensa
Oportunidades de crecimiento
&nbsp;
Descripción completa del empleo
¿Te apasiona transformar datos en estrategias que generen resultados? Esta es tu oportunidad para formar parte de un equipo donde tu análisis tendrá impacto directo en la toma de decisiones comerciales.

Responsabilidades

Analizar información de clientes actuales para identificar oportunidades de crecimiento y fidelización.
Detectar tendencias, patrones y segmentaciones que permitan comprender mejor el comportamiento de los clientes.
Diseñar y automatizar herramientas de análisis de negocio mediante la integración de bases de datos y visualización de información.
Desarrollar dashboards, reportes e informes ejecutivos para la toma de decisiones.
Generar estrategias de Up Selling y Cross Selling que impulsen el crecimiento de la cartera actual.
Mantener actualizada la información de clientes y la plataforma de Inteligencia Comercial.
Colaborar con distintas áreas del negocio para atender necesidades de información y análisis.
Requisitos

Licenciatura o Ingeniería en Mercadotecnia, Administración, Actuaría, Informática, Industrial o afín.
Mínimo 2 años de experiencia en procesamiento y análisis de información.
Excel avanzado.
Experiencia en administración de bases de datos.
Lo que encontrarás

Participarás en proyectos estratégicos que contribuyen al crecimiento comercial de la organización, generando información de valor para la toma de decisiones y el desarrollo de nuevas oportunidades de negocio.

Postúlate y forma parte de un equipo que convierte los datos en estrategias y resultados.

Sueldo: A partir de $12,000.00 al mes

Beneficios:

Seguro de vida
Vales de despensa
Lugar de trabajo: Empleo presencial""",
    """ Descripción completa del empleo
Se busca Ingeniero BI Jr para incorporarse a CONSUBANCO en rol presencial.

Funciones

Gestionar informes y dashboards para el análisis de datos.
Coordinar con equipos de desarrollo para integrar soluciones BI.
Analizar datos para identificar tendencias y oportunidades de mejora.
Colaborar con el equipo de análisis para el desarrollo de proyectos.

Requisitos

Experiencia en análisis de datos y BI.
Conocimiento de herramientas de BI y análisis.
Capacidad para trabajar en equipo y coordinar con diferentes áreas.
Buenas habilidades de comunicación y presentación.

Beneficios

Ofrecemos un ambiente de trabajo dinámico y colaborativo.
Contarás con acceso a formación continua y desarrollo profesional.
Se valora la contribución a proyectos estratégicos de la empresa.

La incorporación en este rol te permitirá crecer profesionalmente y contribuir significativamente al éxito de CONSUBANCO.

""",
    """ Ubicación
72090, Villa San Alejandro, Pue.
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Descuento de empleados
Estacionamiento para empleados
Estacionamiento de la empresa
&nbsp;
Descripción completa del empleo
Lo que vas a hacer

Vas a ser la persona que conecta los números con las decisiones del día a día: qué se está vendiendo, dónde falta inventario, dónde sobra, y qué comprar el próximo mes. Tu trabajo no es solo "hacer reportes" — es dar una recomendación clara que Dirección pueda usar.

Armar y mantener los tableros de venta de las 5 sucursales, listos cada mañana.
Detectar qué productos son estrella (para comprar más) y cuáles están rezagados (para liquidar).
Recomendar traspasos de mercancía entre tiendas para evitar quiebres y sobre-stock, considerando estacionalidad y tendencias — no solo el histórico de venta.
Dar seguimiento semanal con Compras y presentar hallazgos en la junta mensual de resultados.
Construir el pronóstico de venta del siguiente mes, con distintos escenarios.
Lo que buscamos

Formación en Análisis de datos, Economía, Actuaría, Sistemas o carrera afín con enfoque analítico.
PENDIENTE 2-4 años de experiencia o practica en business intelligence, análisis de datos o planeación de compras/inventario. Si fue en retail o moda, es un plus.
Excel avanzado (tablas dinámicas, Power Query) o manejo de Python enfocado en datos; se valora SQL y herramientas de BI (Power BI, Metabase, looker studio).
Capacidad de leer un número y explicar qué significa para el negocio — no solo reportarlo.
Autonomía: este puesto entrega resultados con ritmo fijo (diario, semanal, mensual) y responde directo a Dirección.
Sueldo: $13,000.00 - $15,000.00 al mes

Beneficios:

Descuento de empleados
Estacionamiento de la empresa
Lugar de trabajo: Empleo presencial""",
    """ Descripción completa del empleo
Sniper human Target busca Analista Junior en Naucalpan - Naucalpan de Juárez, Estado de México
Importante Cadena de supermercados, solicita Analista JR de datos


Descripción de Puesto: Analista de Información y Eficiencia Operativa
Área / Departamento: Operaciones / Eficiencia y Procesos
Modalidad: Híbrida (4 días en oficina / 1 día Home Office)*
Tipo de Contrato: Tiempo Completo

Objetivo del Puesto
Optimizar la gestión de datos operativos mediante la elaboración de reportes ejecutivos, el diseño de herramientas de captura y la implementación gradual de automatizaciones e Inteligencia Artificial, asegurando la calidad de la información y la continuidad de los activos operativos.
Responsabilidades Principales
Gestión de Información y Reporteo
Utilizar la paquetería de Microsoft Office para la gestión, estructuración y optimización de datos.


Elaborar reportes y presentaciones ejecutivas para comunicar resultados claros a los distintos niveles de la organización.
Implementar formularios y mecanismos de captura para estandarizar la recolección de datos y garantizar su calidad.
Innovación y Optimización Digital
Capacitarse e implementar herramientas de automatización, programación básica o macros para incrementar la eficiencia operativa.
Explorar e integrar soluciones de Inteligencia Artificial (IA) para potenciar la generación y el análisis avanzado de reportes.

Formación Académica
Licenciatura en Administración, Ingeniería Industrial, Logística, Negocios o carreras afines. (Título no indispensable, valoramos los conocimientos y el empuje).
Conocimientos Deseables
Excel: Nivel intermedio (manejo de funciones, tablas dinámicas, cruces de datos).
PowerPoint: Elaboración de presentaciones ejecutivas y de impacto.
Microsoft Forms / Herramientas de captura.
Bases de Datos: Manejo básico de datos y estructuración de reportes.
Afinidad Tecnológica: Alto interés por la transformación digital, automatización de procesos y herramientas de IA.
Competencias Clave
Proactividad y Autonomía: Capacidad para identificar necesidades y dar seguimiento constante sin requerir supervisión estricta.""",
    """ Ubicación
Ciudad de México, CDMX
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Seguro de gastos médicos mayores
Oportunidades de crecimiento
&nbsp;
Descripción completa del empleo
Analista de Social Listening / Inteligencia DigitalKostik busca Analista Junior de Inteligencia Digital en Cuauhtémoc, Ciudad de México

Estamos buscando un Analista de Inteligencia Digital para integrarse a una consultora especializada en comunicación estratégica e inteligencia digital.

Nuestro cliente desarrolla proyectos para organizaciones e instituciones que necesitan comprender el entorno digital, monitorear conversaciones relevantes y convertir grandes volúmenes de información en inteligencia que apoye la toma de decisiones.

Buscamos una persona analítica, curiosa y con interés por la investigación digital. Alguien que disfrute identificar patrones, conectar información de distintas fuentes y entender qué hay detrás de las conversaciones digitales.

Esta posición va mucho más allá del monitoreo de redes sociales. Buscamos un perfil que quiera desarrollar una carrera en Inteligencia Digital, aprendiendo a transformar datos en análisis estratégicos con impacto para clientes de distintos sectores.

Responsabilidades

Configurar y optimizar búsquedas booleanas para proyectos de monitoreo e investigación.
Monitorear conversaciones en redes sociales, medios digitales, blogs, foros y otras fuentes de información.
Analizar tendencias, narrativas y cambios en la conversación digital.
Revisar, clasificar y validar la calidad de la información recopilada.
Identificar patrones, riesgos y oportunidades relevantes para cada proyecto.
Elaborar reportes periódicos con análisis, hallazgos y recomendaciones.
Crear dashboards y visualizaciones que faciliten la interpretación de la información.-Deseable conocimiento de herramientas como Power BI o Looker Studio.-Interés por el análisis del entorno digital, reputación, tendencias y comportamiento de audiencias.
También valoraremos experiencia en perfiles como:

Investigación digital.
Research.
Consumer Insights.
Inteligencia competitiva.
Análisis de mercados.
Estudios de opinión.
Investigación social o política.
Business Intelligence.
Buscamos personas con

Pensamiento analítico.
Curiosidad por investigar y comprender fenómenos digitales.
Capacidad para identificar patrones y conectar información.
Atención al detalle.
Excelente capacidad de organización.
Buena comunicación escrita y verbal.
Facilidad para explicar información compleja de forma sencilla.
Proactividad para investigar y proponer nuevas ideas.
Capacidad para trabajar bajo presión y responder ante coyunturas relevantes.
Gusto por aprender y desarrollarse en Inteligencia Digital.
Facilidad para colaborar con equipos multidisciplinarios.
Disponibilidad de tiempo completo en fines de semana
Se ofrece

Sueldo mensual de $20,000 a $25,000 MXN, de acuerdo con experiencia.
Seguro de Gastos Médicos Mayores.
Esquema híbrido: lunes a jueves presencial y viernes home office.
Capacitación y desarrollo en herramientas y metodologías de Inteligencia Digital.
Participación en proyectos de alto impacto para organizaciones de distintos sectores.
Oportunidades de crecimiento profesional dentro del área de Inteligencia Digital.
Un entorno dinámico donde podrás desarrollar habilidades analíticas y estratégicas.""",
    """ Ubicación
Miguel Hidalgo, CDMX
&nbsp;
Beneficios
Obtenidos de la descripción completa del empleo

Oportunidades de crecimiento
&nbsp;
Descripción completa del empleo
Analista de Datos Jr. / Operaciones & Servicio al Cliente

En 99minutos buscamos un Analista de Datos Jr. de Operaciones y Servicio al Cliente para integrarse a nuestro equipo. Esta posición es clave para el análisis, actualización y limpieza de bases de datos operativas, combinando el manejo analítico de información en Google Sheets/Excel con el seguimiento y resolución de solicitudes de clientes a través de plataformas CRM y sistemas de ticketing.

Si cuentas con gusto por el análisis de datos, agilidad en herramientas de hoja de cálculo y experiencia en áreas de atención a clientes u operaciones, ¡queremos conocerte!

Principales funciones:
Análisis y gestión de datos: Elaborar, actualizar y dar seguimiento a reportes operativos y bases de datos en Excel/Google Sheets para el control de la operación.
Gestión de solicitudes: Atender, canalizar y dar seguimiento a requerimientos de clientes internos y externos a través de CRM o sistema de ticketing.
Documentación y control: Registrar detalladamente cada caso en sistema, garantizando la precisión y limpieza de la información capturada.
Resolución e incidencias: Gestionar tickets relacionados con dudas, aclaraciones o seguimiento operativo, escalando los casos con áreas internas según corresponda.
Monitoreo de SLAs: Dar seguimiento puntual a casos abiertos asegurando el cumplimiento de los tiempos de respuesta y niveles de servicio.
Perfil:
Formación académica: Licenciatura trunca o concluida (Lic. en Administración, Negocios, Mercadotecnia, Ingeniería o afines).
Manejo de hojas de cálculo (Indispensable): Google Sheets / Excel a nivel Básico - Intermedio (manejo de tablas dinámicas, cruces de información, fórmulas de búsqueda como BUSCARV/VLOOKUP y limpieza de datos).
Experiencia previa: Deseable de 6 meses a 1 año en análisis de datos operacionales, mes de control, soporte/atención al cliente multicanal o gestión de tickets en herramientas CRM (Zendesk, Salesforce, etc.).
Habilidades clave: Excelente redacción y ortografía, atención al detalle, sentido de urgencia, capacidad analítica y orientación a resultados.
Ofrecemos:
Sueldo bruto mensual: $12,000 MXN brutos
Prestaciones de Ley desde el primer día + SGMM
Ubicación presencial: Polanco, CDMX.
Esquema de trabajo Híbrido:
3 días presenciales en oficina: Lunes, Miércoles y Viernes (9:00 a.m. a 6:00 p.m.).
3 días en Home Office: Martes y Jueves (9:00 a.m. a 6:00 p.m.) y Sábados (9:00 a.m. a 4:00 p.m.).
Oportunidad de desarrollo dentro de una de las empresas de logística e-commerce con mayor crecimiento.
""",
    """ Ubicación
11000, Colonia Lomas de Chapultepec, CDMX
&nbsp;
Descripción completa del empleo
Job Title


Audit Services Jr




Employment Type


Full time



Work Authorization Requirements


Authorized to work in Mexico without sponsorship



Language Requirements


English, Desirable



About PRGX

PRGX is the global leader in source-to-pay data analytics and software, and tech-enabled profit recovery services. We provide software and services to maximize revenue recovery and drive margin improvement for our clients. For more information about PRGX, visit www.prgx.com.


Job Duties & Responsibilities

Design, develop, and maintain applications.
Develop, manage, and optimize databases using SQL.
Write and maintain code using SQL and Visual Basic for Applications.
Install, configure, monitor, and administer database systems.
Execute, analyze, and optimize SQL queries for performance improvement.
Understand and manage database structures and schemas.
Provide technical support across multicultural projects.
Offer support and assistance to end users, troubleshooting issues as needed.
Prioritize and execute tasks effectively in a fast-paced, high-pressure environment.
Analyze information and support decision-making processes.

Knowledge & Qualifications

Recently graduated with a Bachelor’s degree in Computer Systems Engineering, Information Technology, or a related field.
Intermediate level of SQL.
Intermediate level of Visual Basic for Applications
Strong analytical and problem-solving skills.
Ability to work in a team and communicate effectively.
Intermediate level of English
Optional: Python or data processing (OCR)

Our Commitment to Equal Opportunity

PRGX is an equal opportunity employer. We comply with all applicable local, national, and international laws regarding non-discrimination and equal employment. We do not discriminate based on any legally protected characteristic and are committed to fostering an inclusive, respectful, and equitable workplace. Reasonable accommodations are available for qualified individuals in accordance with local laws and best practices.


Physical Requirements

Ability to sit or stand for extended periods of time, manual dexterity for typing, writing, or using office equipment, visual acuity for reading screens and documents, ability to lift or carry light items such as laptops, and speech and hearing ability for calls, virtual meetings, and in-person communication


Data Privacy

Your personal data will be handled in accordance with applicable data protection laws. We only collect information necessary for recruitment and will not share your data without your consent.

WORKING CONDITIONS AND EQUAL EMPLOYMENT

Any physical demands described are representative of those that must be met by an employee to successfully perform the essential functions of the described job. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions. While performing the duties of this job, the employee is occasionally required to remain stationary; move; lift and/or move up to 15 pounds. The employee must regularly sit; use hands to finger, handle, or feel; reach with hands and arms; communicate. Specific vision abilities required by this job include close vision.

PRGX does not discriminate against employees or applicants for employment based upon race, color, national origin, genetic information, religious beliefs, gender, age, marital status, disability, veteran status, or any other protected classifications, activities, or conditions as required by federal, state and local laws.""",
    """ UESTO: Analista de Datos Jr


Objetivo del Puesto


Diseñar, desarrollar y mantener dashboards, modelos de datos y procesos de integración de información para la toma de decisiones de la compañía, garantizando la calidad, disponibilidad y confiabilidad de los datos utilizados por las áreas operativas, comerciales y directivas.


Requisitos Indispensables


Conocimiento en desarrollando dashboards y soluciones de Business Intelligence, manejo de herramientas de IA y programación.
Recién egresado de Licenciatura o Ingeniería en Sistemas, Informática, Actuaría, Matemáticas, Ingeniería Industrial, Ciencia de Datos o afín.
Experiencia ó Conocimiento en el manejo de Power BI.
Experiencia ó conocimiento en SQL Server.
Experiencia ó conocimiento en modelado de datos y bases de datos relacionales.
Experiencia ó conocimiento en Power Query y DAX.
Excel medio.
Inglés intermedio.
Conocimiento de herramientas IA

Conocimientos Técnicos


Power BI Desktop y Power BI Service.
DAX (medidas, columnas calculadas, tablas calculadas).
Power Query.
SQL avanzado (JOINs, CTEs, subconsultas, vistas, procedimientos almacenados).
Modelado dimensional (esquema estrella).
ETL y transformación de datos.
Integración de información desde múltiples fuentes.
Python (deseable).
Inteligencia Artificial aplicada al análisis de datos (deseable).

Responsabilidades


Desarrollar y mantener dashboards corporativos en Power BI.
Diseñar modelos de datos eficientes para análisis comercial, financiero y operativo.
Crear consultas SQL para extracción, transformación y validación de información.
Automatizar procesos de generación y actualización de reportes.
Garantizar la calidad y consistencia de los datos utilizados por la organización.
Atender requerimientos de información de Dirección y áreas operativas.
Documentar procesos, modelos de datos y métricas de negocio.
Identificar oportunidades de automatización y mejora de procesos mediante análisis de datos.

Indicadores de Desempeño


Disponibilidad y actualización oportuna de dashboards.
Tiempo de respuesta a requerimientos.
Calidad de información entregada.
Automatizaciones implementadas.
Reducción de procesos manuales.
Satisfacción de usuarios internos.

Habilidades


Pensamiento analítico.
Atención al detalle.
Proactividad.
Organización y administración del tiempo.
Comunicación efectiva.
Orientación a resultados.
Capacidad para resolver problemas.
Trabajo en equipo.
""",
    """ bicación
Venustiano Carranza, CDMX
&nbsp;
Descripción completa del empleo
PUESTO: Analista de Datos Jr


Objetivo del Puesto


Diseñar, desarrollar y mantener dashboards, modelos de datos y procesos de integración de información para la toma de decisiones de la compañía, garantizando la calidad, disponibilidad y confiabilidad de los datos utilizados por las áreas operativas, comerciales y directivas.


Requisitos Indispensables


Conocimiento en desarrollando dashboards y soluciones de Business Intelligence, manejo de herramientas de IA y programación.
Recién egresado de Licenciatura o Ingeniería en Sistemas, Informática, Actuaría, Matemáticas, Ingeniería Industrial, Ciencia de Datos o afín.
Experiencia ó Conocimiento en el manejo de Power BI.
Experiencia ó conocimiento en SQL Server.
Experiencia ó conocimiento en modelado de datos y bases de datos relacionales.
Experiencia ó conocimiento en Power Query y DAX.
Excel medio.
Inglés intermedio.
Conocimiento de herramientas IA

Conocimientos Técnicos


Power BI Desktop y Power BI Service.
DAX (medidas, columnas calculadas, tablas calculadas).
Power Query.
SQL avanzado (JOINs, CTEs, subconsultas, vistas, procedimientos almacenados).
Modelado dimensional (esquema estrella).
ETL y transformación de datos.
Integración de información desde múltiples fuentes.
Python (deseable).
Inteligencia Artificial aplicada al análisis de datos (deseable).

Responsabilidades


Desarrollar y mantener dashboards corporativos en Power BI.
Diseñar modelos de datos eficientes para análisis comercial, financiero y operativo.
Crear consultas SQL para extracción, transformación y validación de información.
Automatizar procesos de generación y actualización de reportes.
Garantizar la calidad y consistencia de los datos utilizados por la organización.
Atender requerimientos de información de Dirección y áreas operativas.
Documentar procesos, modelos de datos y métricas de negocio.
Identificar oportunidades de automatización y mejora de procesos mediante análisis de datos.

Indicadores de Desempeño


Disponibilidad y actualización oportuna de dashboards.
Tiempo de respuesta a requerimientos.
Calidad de información entregada.
Automatizaciones implementadas.
Reducción de procesos manuales.
Satisfacción de usuarios internos.

Habilidades


Pensamiento analítico.
Atención al detalle.
Proactividad.
Organización y administración del tiempo.
Comunicación efectiva.
Orientación a resultados.
Capacidad para resolver problemas.
Trabajo en equipo.""",
]

print(f"Total job postings loaded: {len(job_postings)}")
# Out:
# Total job postings loaded: 27

# %%
#3
def extract_job_info(job_text):
    response = requests.post(
        "https://api.anthropic.com/v1/messages",
        headers={
            "x-api-key": api_key,
            "anthropic-version": "2023-06-01",
            "content-type": "application/json"
        },
        json={
            "model": "claude-sonnet-4-6",
            "max_tokens": 500,
            "messages": [
                {
                    "role": "user",
                    "content": f"""Extract the following from this job posting and return ONLY a JSON object, no extra text:

- job_title (string)
- company (string, use "Unknown" if not found)
- required_skills (list of strings, standardize ALL skill names using these rules:
    - Use "Excel" for: Excel Avanzado, Microsoft Excel, Google Sheets, VLOOKUP, Tablas dinamicas, PowerPoint, Microsoft Office, Office
    - Use "Power BI" for: DAX, Power Query, Dataflow, Dataset, Power BI/DAX
    - Use "SQL" for: SQL Avanzado
    - Use "Data Analysis" for: Análisis de datos, Data Analytics, Pensamiento analitico, Analytical Skills
    - Use "Reporting" for: Reportes, Reportes ejecutivos, Elaboracion de reportes, informes
    - Use "Dashboards" for: Dashboard Design, Dashboard Development, Tableros de control
    - Use "Database Management" for: Bases de datos, Administracion de bases de datos, Gestion de bases de datos
    - Use "Business Intelligence" for: Herramientas de BI, BI Tools
    - Use "Inteligencia Artificial" for: AI, Artificial Intelligence, AI Tools, ChatGPT, Copilot, Gemini
    - Use "ETL" for: ETL/ELT
    - Use "Data Visualization" for: Visualizacion de datos
    - Use your own judgment to group any other similar or equivalent skills not listed above into their most appropriate standardized category. For example if you see "Looker" group it with "Data Visualization", if you see "Pandas" group it with "Python". Prioritize consistency over specificity.)
- experience_years_min (number, use 0 if not found)
- experience_years_max (number, use 0 if not found)
- seniority (string: "Junior", "Mid", or "Senior")
- language_required (string: "Spanish", "English", or "Both")

Job posting:
{job_text}"""
                }
            ]
        }
    )
    raw = response.json()["content"][0]["text"]
    clean = raw.replace("```json", "").replace("```", "").strip()
    return json.loads(clean)

# test on first posting only
print(extract_job_info(job_postings[0]))
# Out:
# {'job_title': 'Spec Analytics Analyst', 'company': 'Citigroup', 'required_skills': ['SQL', 'Python', 'Data Analysis', 'Data Visualization', 'Inteligencia Artificial', 'Machine Learning', 'Database Management', 'Reporting'], 'experience_years_min': 0, 'experience_years_max': 2, 'seniority': 'Junior', 'language_required': 'Both'}

# %%
# Cell 4
results = []

for i, posting in enumerate(job_postings):
    print(f"Processing job {i+1}...")
    parsed = extract_job_info(posting)
    results.append(parsed)

df_jobs = pd.DataFrame(results)
df_jobs["job_id"] = range(1, len(df_jobs) + 1)  # add this line
print(df_jobs)
# Out:
# Processing job 1...
# Processing job 2...
# Processing job 3...
# Processing job 4...
# Processing job 5...
# Processing job 6...
# Processing job 7...
# Processing job 8...
# Processing job 9...
# Processing job 10...
# Processing job 11...
# Processing job 12...
# Processing job 13...
# Processing job 14...
# Processing job 15...
# Processing job 16...
# Processing job 17...
# Processing job 18...
# Processing job 19...
# Processing job 20...
# Processing job 21...
# Processing job 22...
# Processing job 23...
# Processing job 24...
# Processing job 25...
# Processing job 26...
# Processing job 27...
#                                             job_title  \
# 0                              Spec Analytics Analyst
# 1                              Data Analyst Associate
# 2                        Analista BI / Data Analytics
# 3        Data Analyst / Business Intelligence Analyst
# 4                      Business Operations Analyst II
# ...

# %%
#5
# explode skills into individual rows
df_skills_clean = df_jobs.explode("required_skills").reset_index(drop=True)
df_skills_clean = df_skills_clean.rename(columns={"required_skills": "skill"})

print(df_skills_clean["skill"].value_counts().head(15))
# Out:
# skill
# Data Analysis              24
# Reporting                  21
# Excel                      19
# Power BI                   17
# Database Management        16
# SQL                        16
# Dashboards                 14
# Python                      9
# Business Intelligence       9
# Data Visualization          9
# Inteligencia Artificial     7
# ETL                         7
# Statistics                  2
# Inventory Management        2
# Data Modeling               2
# Name: count, dtype: int64

# %%
#6
df_jobs.to_csv("jobs_analysisAIFinal.csv", index=False)
df_skills_clean.to_csv("skills_analysisAIFinal.csv", index=False)

print("Exported successfully")
print(f"Total jobs analyzed: {len(df_jobs)}")
print(f"Total skill mentions: {len(df_skills_clean)}")
# Out:
# Exported successfully
# Total jobs analyzed: 27
# Total skill mentions: 193
